# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('/content/Student_performance_data _.csv')
train_data
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
train_data.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# ...

# %%
train_data.tail(10)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2382       3383   16       0          0                  3        13.941823
# 2383       3384   16       1          2                  2        11.736409
# 2384       3385   15       1          0                  1        16.655581
# 2385       3386   16       1          0                  1         1.445434
# 2386       3387   16       0          0                  2        13.814021
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   int64
# dtypes: float64(2), int64(13)
# memory usage: 280.4 KB

# %%
train_data.shape
# Out:
# (2392, 15)

# %%
train_data.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(2,3))
plt.bar(['female','male'],train_data['Gender'].value_counts())
plt.show()

# %%
sns.histplot(train_data['Absences'],kde=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
x=train_data.drop('GPA',axis=1)
y = train_data['GradeClass']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rt=RandomForestClassifier()
rt.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rt.predict(x_test)
y_pred
# Out:
# array([4, 1, 2, 0, 4, 2, 3, 3, 3, 4, 1, 4, 2, 2, 2, 4, 4, 4, 3, 3, 4, 4,
#        4, 1, 4, 4, 4, 1, 3, 3, 3, 4, 2, 1, 4, 4, 1, 0, 1, 4, 2, 0, 4, 3,
#        4, 3, 2, 4, 1, 4, 1, 1, 4, 4, 4, 1, 0, 1, 4, 3, 4, 3, 3, 4, 4, 4,
#        4, 3, 4, 1, 0, 4, 2, 2, 4, 2, 3, 4, 4, 4, 3, 2, 3, 4, 4, 4, 0, 4,
#        3, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 4, 3, 4, 1, 4, 3, 2, 4, 4, 4,
#        4, 3, 2, 4, 4, 4, 3, 3, 4, 3, 4, 1, 0, 4, 4, 4, 2, 4, 3, 2, 4, 0,
#        2, 4, 4, 4, 3, 4, 4, 4, 2, 4, 1, 4, 2, 4, 4, 2, 3, 4, 1, 4, 0, 4,
#        4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 3, 0, 4, 1, 2, 4, 4, 2,
#        3, 4, 3, 4, 2, 4, 4, 2, 0, 2, 1, 3, 4, 4, 4, 3, 4, 4, 4, 4, 4, 3,
#        2, 3, 4, 1, 4, 2, 2, 3, 4, 2, 3, 4, 4, 4, 4, 2, 2, 4, 2, 1, 4, 2,
#        4, 2, 0, 4, 4, 4, 1, 2, 4, 4, 4, 3, 2, 4, 2, 2, 4, 1, 2, 4, 0, 4,
#        4, 3, 4, 4, 3, 4, 4, 3, 4, 2, 3, 4, 3, 4, 4, 3, 4, 4, 3, 4, 4, 4,
#        4, 1, 3, 4, 2, 3, 4, 3, 4, 4, 4, 3, 4, 4, 4, 2, 1, 2, 4, 4, 1, 3,
# ...

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9958246346555324

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([4, 1, 2, 0, 4, 2, 3, 3, 3, 4, 1, 4, 2, 2, 2, 4, 4, 4, 3, 3, 4, 4,
#        4, 1, 4, 4, 4, 1, 3, 3, 3, 4, 2, 1, 4, 4, 1, 0, 1, 4, 2, 0, 4, 3,
#        4, 3, 2, 4, 0, 4, 1, 1, 4, 4, 4, 1, 0, 1, 4, 3, 4, 3, 3, 4, 4, 4,
#        4, 3, 4, 1, 0, 4, 2, 2, 4, 2, 3, 4, 4, 4, 3, 2, 3, 4, 4, 4, 0, 4,
#        3, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 4, 3, 4, 1, 4, 3, 2, 4, 4, 4,
#        4, 3, 2, 4, 4, 4, 3, 3, 4, 3, 4, 1, 0, 4, 4, 4, 2, 4, 3, 2, 4, 0,
#        2, 4, 4, 4, 3, 4, 4, 4, 2, 4, 1, 4, 2, 4, 4, 2, 3, 4, 1, 4, 0, 4,
#        4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 3, 0, 4, 1, 2, 4, 4, 2,
#        3, 4, 3, 4, 2, 4, 4, 2, 0, 2, 1, 3, 4, 4, 4, 3, 4, 4, 4, 4, 4, 3,
#        2, 3, 4, 1, 4, 2, 2, 3, 4, 2, 3, 4, 4, 4, 4, 2, 2, 4, 2, 1, 4, 2,
#        4, 2, 0, 4, 4, 4, 1, 2, 4, 4, 4, 3, 2, 4, 2, 2, 4, 1, 2, 4, 0, 4,
#        4, 3, 4, 4, 3, 4, 4, 3, 4, 2, 3, 4, 3, 4, 4, 3, 4, 4, 3, 4, 4, 4,
#        4, 1, 3, 4, 2, 3, 4, 3, 4, 4, 4, 3, 4, 4, 4, 2, 1, 2, 4, 4, 1, 3,
# ...

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 1.0

# %%
GPA=dt.predict(x_test)
GPA
# Out:
# array([4, 1, 2, 0, 4, 2, 3, 3, 3, 4, 1, 4, 2, 2, 2, 4, 4, 4, 3, 3, 4, 4,
#        4, 1, 4, 4, 4, 1, 3, 3, 3, 4, 2, 1, 4, 4, 1, 0, 1, 4, 2, 0, 4, 3,
#        4, 3, 2, 4, 0, 4, 1, 1, 4, 4, 4, 1, 0, 1, 4, 3, 4, 3, 3, 4, 4, 4,
#        4, 3, 4, 1, 0, 4, 2, 2, 4, 2, 3, 4, 4, 4, 3, 2, 3, 4, 4, 4, 0, 4,
#        3, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 4, 3, 4, 1, 4, 3, 2, 4, 4, 4,
#        4, 3, 2, 4, 4, 4, 3, 3, 4, 3, 4, 1, 0, 4, 4, 4, 2, 4, 3, 2, 4, 0,
#        2, 4, 4, 4, 3, 4, 4, 4, 2, 4, 1, 4, 2, 4, 4, 2, 3, 4, 1, 4, 0, 4,
#        4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 3, 0, 4, 1, 2, 4, 4, 2,
#        3, 4, 3, 4, 2, 4, 4, 2, 0, 2, 1, 3, 4, 4, 4, 3, 4, 4, 4, 4, 4, 3,
#        2, 3, 4, 1, 4, 2, 2, 3, 4, 2, 3, 4, 4, 4, 4, 2, 2, 4, 2, 1, 4, 2,
#        4, 2, 0, 4, 4, 4, 1, 2, 4, 4, 4, 3, 2, 4, 2, 2, 4, 1, 2, 4, 0, 4,
#        4, 3, 4, 4, 3, 4, 4, 3, 4, 2, 3, 4, 3, 4, 4, 3, 4, 4, 3, 4, 4, 4,
#        4, 1, 3, 4, 2, 3, 4, 3, 4, 4, 4, 3, 4, 4, 4, 2, 1, 2, 4, 4, 1, 3,
# ...

# %%
def grade_from_gpa(GPA):
  if GPA>=3.5:
    return 'A'
  elif 3.0<=GPA<=3.5:
    return 'B'
  elif 2.5<=GPA<=3.0:
    return 'C'
  elif 2.0<=GPA<2.5:
    return 'D'
  else:
    return 'F'
grade=[]
for item in GPA:
  df3=grade_from_gpa(item)
  grade.append(df3)

# %%
x_test['Grade']=grade

# %%
x_test
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1004       2005   15       1          2                  4         0.135763
# 196        1197   16       1          0                  4         1.989925
# 2342       3343   15       0          0                  0        10.588715
# 1708       2709   18       1          1                  2        16.208658
# 435        1436   18       0          0                  0         3.576821
# ...         ...  ...     ...        ...                ...              ...
# 986        1987   18       1          0                  2         8.412605
# 120        1121   18       1          0                  3         3.170405
# 283        1284   17       0          0                  1         5.141922
# 1740       2741   18       1          1                  0        10.281614
# 1726       2727   18       1          0                  0        15.610436
#
# ...
